# %%
import pandas as pd


df = pd.read_csv("./TPE.csv").T
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df.to_csv("./TPE_T.csv", index=False)

# %%
# df1 = pd.read_csv("./ParaSuit_t.csv")
df = pd.read_csv("./SucHalving_t.csv")
# df3 = pd.read_csv("./TPE_t.csv")

# %%
# df = pd.concat([df1, df2, df3], ignore_index=True)

df
# Out:
#     switch-type  max-memory-inhibit  max-sym-array-size  max-depth  watchdog  \
# 0      internal                True                4096       2000     False
# 1        simple               False              295047     139489      True
# 2          llvm               False               41555     129896     False
# 3        simple                True              152827      75189     False
# 4          llvm                True              243590      18679     False
# ..          ...                 ...                 ...        ...       ...
# 346        llvm               False              392117     182049     False
# 347      simple               False              172182     172287     False
# 348        llvm               False              301785     183480     False
# 349    internal                True              246140       9248     False
# 350    internal                True               27848      54518     False
#
#      max-static-fork-pct  const-array-opt  zero-seed-extension  \
# 0                 1.0000            False                False
# 1                 0.1388            False                False
# 2                 0.8810            False                False
# 3                 0.7200            False                 True
# 4                 0.6378             True                False
# ..                   ...              ...                  ...
# 346               0.3484             True                False
# 347               0.8551             True                False
# 348               0.8567             True                False
# 349               0.5163            False                 True
# 350               0.5577            False                 True
#
#     smtlib-display-constants  warnings-only-to-file  ...  batch-time  \
# 0                        dec                  False  ...          5s
# 1                        dec                  False  ...         31s
# 2                        bin                  False  ...         27s
# 3                        bin                  False  ...         10s
# 4                        bin                   True  ...         32s
# ..                       ...                    ...  ...         ...
# 346                      hex                   True  ...         34s
# 347                      bin                  False  ...         23s
# 348                      hex                  False  ...         26s
# 349                      bin                   True  ...         18s
# 350                      bin                  False  ...         18s
#
#      max-static-solve-pct  max-static-cpfork-pct  max-static-cpsolve-pct  \
# 0                  1.0000                 1.0000                  1.0000
# 1                  0.4331                 0.1532                  0.9636
# 2                  0.1365                 0.4742                  0.1505
# 3                  0.9881                 0.5712                  0.5506
# 4                  0.1919                 0.4550                  0.8895
# ..                    ...                    ...                     ...
# 346                0.2026                 0.4189                  0.4615
# 347                0.4633                 0.7578                  0.8175
# 348                0.5288                 0.6174                  0.3892
# 349                0.5605                 0.0972                  0.7542
# 350                0.5532                 0.7153                  0.9185
#
#      array-value-symb-ratio                      sym-arg  sym-flies  \
# 0                    1.0000              [4, 5, 1, 2, 2]        1 8
# 1                    0.1001                      [14, 1]       1 17
# 2                    0.1236   [14, 8, 8, 13, 15, 16, 12]       1 28
# 3                    0.1860         [20, 19, 20, 20, 20]       1 22
# 4                    0.5384  [18, 18, 2, 14, 14, 10, 16]       1 21
# ..                      ...                          ...        ...
# 346                  0.6207                          [3]        1 3
# 347                  0.4069                     [15, 15]        2 3
# 348                  0.9323                   [1, 9, 14]        2 5
# 349                  0.4627      [16, 14, 6, 14, 16, 12]       2 18
# 350                  0.2869       [20, 3, 6, 3, 3, 6, 6]       1 14
#
#      sym-stdin  Coverage  Accumulated Coverage
# 0            8      1169                  1169
# 1           55      1395                  1487
# 2           58      2076                  2154
# 3           51      1355                  2157
# 4           74      2018                  2205
# ..         ...       ...                   ...
# 346         72      1628                  3456
# 347         44      2304                  3456
# 348         21         0                  3456
# 349         17      1654                  3456
# 350         69      1008                  3456
#
# [351 rows x 60 columns]

# %%
time = ['seed-time', 'uncovered-update-interval', 'max-solver-time', 'batch-time']
for t in time:
    df[t] = df[t].apply(lambda x: str(x).replace('s', ''))
    df[t] = pd.to_numeric(df[t], errors='coerce').astype(int)

# %%
df = df.drop(columns=["sym-arg", "sym-flies", "Accumulated Coverage"], axis=1)
df
# Out:
#     switch-type  max-memory-inhibit  max-sym-array-size  max-depth  watchdog  \
# 0      internal                True                4096       2000     False
# 1        simple               False              295047     139489      True
# 2          llvm               False               41555     129896     False
# 3        simple                True              152827      75189     False
# 4          llvm                True              243590      18679     False
# ..          ...                 ...                 ...        ...       ...
# 346        llvm               False              392117     182049     False
# 347      simple               False              172182     172287     False
# 348        llvm               False              301785     183480     False
# 349    internal                True              246140       9248     False
# 350    internal                True               27848      54518     False
#
#      max-static-fork-pct  const-array-opt  zero-seed-extension  \
# 0                 1.0000            False                False
# 1                 0.1388            False                False
# 2                 0.8810            False                False
# 3                 0.7200            False                 True
# 4                 0.6378             True                False
# ..                   ...              ...                  ...
# 346               0.3484             True                False
# 347               0.8551             True                False
# 348               0.8567             True                False
# 349               0.5163            False                 True
# 350               0.5577            False                 True
#
#     smtlib-display-constants  warnings-only-to-file  ...  cex-cache-superset  \
# 0                        dec                  False  ...               False
# 1                        dec                  False  ...               False
# 2                        bin                  False  ...                True
# 3                        bin                  False  ...                True
# 4                        bin                   True  ...               False
# ..                       ...                    ...  ...                 ...
# 346                      hex                   True  ...               False
# 347                      bin                  False  ...                True
# 348                      hex                  False  ...                True
# 349                      bin                   True  ...                True
# 350                      bin                  False  ...               False
#
#      verify-each  max-memory  batch-time  max-static-solve-pct  \
# 0          False        2000           5                1.0000
# 1           True      172194          31                0.4331
# 2           True      196178          27                0.1365
# 3           True      167663          10                0.9881
# 4          False      161889          32                0.1919
# ..           ...         ...         ...                   ...
# 346        False      126071          34                0.2026
# 347        False       83495          23                0.4633
# 348        False      190907          26                0.5288
# 349         True      187173          18                0.5605
# 350         True      151150          18                0.5532
#
#      max-static-cpfork-pct  max-static-cpsolve-pct  array-value-symb-ratio  \
# 0                   1.0000                  1.0000                  1.0000
# 1                   0.1532                  0.9636                  0.1001
# 2                   0.4742                  0.1505                  0.1236
# 3                   0.5712                  0.5506                  0.1860
# 4                   0.4550                  0.8895                  0.5384
# ..                     ...                     ...                     ...
# 346                 0.4189                  0.4615                  0.6207
# 347                 0.7578                  0.8175                  0.4069
# 348                 0.6174                  0.3892                  0.9323
# 349                 0.0972                  0.7542                  0.4627
# 350                 0.7153                  0.9185                  0.2869
#
#      sym-stdin  Coverage
# 0            8      1169
# 1           55      1395
# 2           58      2076
# 3           51      1355
# 4           74      2018
# ..         ...       ...
# 346         72      1628
# 347         44      2304
# 348         21         0
# 349         17      1654
# 350         69      1008
#
# [351 rows x 57 columns]

# %%
df.to_csv("dataset2.csv", index=False)
